# %%
# 외부에 정의된 모듈 판다스를 가지고 와서 사용할 것
# pandas를 pd라는 별칭으로 부름
import pandas as pd

# %%
# 판다스 모듈에 있는 read_csv 명령으로 컴퓨터에 있는 파일(sample.csv)을 df라는 변수에 넣어 줌
# pd.read_csv("파일경로입력_문자열")

df = pd.read_csv('/content/drive/MyDrive/스마트공장AI/sample.csv')
display(df)
# Out:
#    bun name  kor  eng bigo
# 0    1   aa   70   68  NaN
# 1    2   bb   85   88  NaN
# 2    3   cc   96   92  Yes
# 3    4   dd   48   37   No
# 4    5   ee   85   79  NaN
# 5    6   ff   88   88  NaN
# 6    7   gg   57   55   No
# 7    8   hh   72   79  NaN

# %%
df.info()   # info()를 통해 데이터프레임의 정보를 확인,
            # 파이썬에서 null은 비정상적이거나 없는 값(null과 NaN을 구분하지 않고 null으로)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   bun     8 non-null      int64
#  1   name    8 non-null      object
#  2   kor     8 non-null      int64
#  3   eng     8 non-null      int64
#  4   bigo    3 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 448.0+ bytes

# %%
# 파이썬에서 인코딩 방식은 기본 정의된 값은 UTF-8 형식이며,
# 인코딩 방식을 따로 지정하지 않는다면 UTF-8로 불러온다.
# 하지만 윈도우에서 한글을 사용하여 파일을 생성하면 대부분 euc-kr로 생성되며
# euc-kr 형식을 불러올 때 인코딩 형식을 지정해 줘야 한다.
# euc-kr은 다른 말로 cp949라고도 한다.

df_ko = pd.read_csv('/content/drive/MyDrive/스마트공장AI/sample_ko.csv')
# df_ko = pd.read_csv('/content/drive/MyDrive/스마트공장AI/sample_ko.csv', encoding='euc-kr')
display(df_ko)
# Out:
#    번호  이름  국어  영어   비고
# 0   1  aa  70  68  NaN
# 1   2  bb  85  88  NaN
# 2   3  cc  96  92  우수자
# 3   4  dd  48  37  재수강
# 4   5  ee  85  79  NaN
# 5   6  ff  88  88  NaN
# 6   7  gg  57  55  재수강
# 7   8  hh  72  79  NaN

# %%
df_ko.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   번호      8 non-null      int64
#  1   이름      8 non-null      object
#  2   국어      8 non-null      int64
#  3   영어      8 non-null      int64
#  4   비고      3 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 448.0+ bytes

# %%
df_ko['이름']
# Out:
# 0    aa
# 1    bb
# 2    cc
# 3    dd
# 4    ee
# 5    ff
# 6    gg
# 7    hh
# Name: 이름, dtype: object

# %%
# 여러 컬럼을 볼 수 있는데, 출력할 컬럼이 1개 이상이라면,
# 리스트로 묶어서 입력한다. ex:['이름', '영어', '국어']
df_ko[['이름', '영어', '국어']]
# Out:
#    이름  영어  국어
# 0  aa  68  70
# 1  bb  88  85
# 2  cc  92  96
# 3  dd  37  48
# 4  ee  79  85
# 5  ff  88  88
# 6  gg  55  57
# 7  hh  79  72

# %%
df.head()   # 입력파라미터가 생략되면 디폴트값은 5이다.
# Out:
#    bun name  kor  eng bigo
# 0    1   aa   70   68  NaN
# 1    2   bb   85   88  NaN
# 2    3   cc   96   92  Yes
# 3    4   dd   48   37   No
# 4    5   ee   85   79  NaN

# %%
df.head(2)
# Out:
#    bun name  kor  eng bigo
# 0    1   aa   70   68  NaN
# 1    2   bb   85   88  NaN

# %%
df.tail()
# Out:
#    bun name  kor  eng bigo
# 3    4   dd   48   37   No
# 4    5   ee   85   79  NaN
# 5    6   ff   88   88  NaN
# 6    7   gg   57   55   No
# 7    8   hh   72   79  NaN

# %%
df.tail(3)
# Out:
#    bun name  kor  eng bigo
# 5    6   ff   88   88  NaN
# 6    7   gg   57   55   No
# 7    8   hh   72   79  NaN

# %%
df.columns
# Out:
# Index(['bun', 'name', 'kor', 'eng', 'bigo'], dtype='object')

# %%
df.columns[1]
# Out:
# 'name'

# %%
df[df.columns[1]]
# Out:
# 0    aa
# 1    bb
# 2    cc
# 3    dd
# 4    ee
# 5    ff
# 6    gg
# 7    hh
# Name: name, dtype: object

# %%
df.columns[0]+df.columns[1]
# Out:
# 'bunname'

# %%
df.values   # 데이터프레임에 있는 값만 확인
# Out:
# array([[1, 'aa', 70, 68, nan],
#        [2, 'bb', 85, 88, nan],
#        [3, 'cc', 96, 92, 'Yes'],
#        [4, 'dd', 48, 37, 'No'],
#        [5, 'ee', 85, 79, nan],
#        [6, 'ff', 88, 88, nan],
#        [7, 'gg', 57, 55, 'No'],
#        [8, 'hh', 72, 79, nan]], dtype=object)

# %%
# 데이터 정렬
# 오름차순 = 거짓 -> 내림차순 = 큰수부터 나열
df.sort_values(by='kor', ascending=False).head(3)
# Out:
#    bun name  kor  eng bigo
# 2    3   cc   96   92  Yes
# 5    6   ff   88   88  NaN
# 1    2   bb   85   88  NaN

# %%
# 오름차순 = 참 -> 오름차순 작은 수부터 나열
df.sort_values(by='kor', ascending=True).head(3)
# df.sort_values(by='kor').head(3) -> ascending=True는 생략 가능
# Out:
#    bun name  kor  eng bigo
# 3    4   dd   48   37   No
# 6    7   gg   57   55   No
# 0    1   aa   70   68  NaN

# %%
# 통계 출력
df.describe()   # name, bigo는 연산되지 않기에 생략됨
# Out:
#            bun        kor       eng
# count  8.00000   8.000000   8.00000
# mean   4.50000  75.125000  73.25000
# std    2.44949  16.461535  19.00188
# min    1.00000  48.000000  37.00000
# 25%    2.75000  66.750000  64.75000
# 50%    4.50000  78.500000  79.00000
# 75%    6.25000  85.750000  88.00000
# max    8.00000  96.000000  92.00000

# %%
# 카운트만 출력
df.count()
# Out:
# bun     8
# name    8
# kor     8
# eng     8
# bigo    3
# dtype: int64

# %%
# 표준편차만 출력
df.std()    # name, bigo는 연산이 안되기에 출력 안됨
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# bun     2.449490
# kor    16.461535
# eng    19.001880
# dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.plot(df['eng'], color='k', linestyle='-', marker='*',
         markerfacecolor='r', markersize=20)
plt.show()

# %%
# 산점도 그래프
# plt.scatter(x축, y축, s는 마커 크기)
plt.scatter(df['kor'], df['eng'], s=50)
plt.show()

# %%
# 막대 그래프
df['eng'].plot(kind='bar', grid=True, figsize=(10,5))
plt.show()

# %%
df['eng'].plot(kind='barh', grid=True, figsize=(10,5))
plt.show()
